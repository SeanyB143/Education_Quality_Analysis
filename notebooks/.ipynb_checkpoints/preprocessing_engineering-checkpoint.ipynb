# %% [markdown]
# > In this notebook, we import the three formatted data frames: UIS, PISA, and World Bank. We scale each feature to have a minimum of .9 and maximum of 1.1, and multiply each feature to create our three indexes: school climate, school resources, and learning outcomes. We rescale our indexes and multiply again to create our overall education quality index.

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
uis = pd.read_csv('../data/UIS/uis.csv', index_col='Year_Country')
pisa = pd.read_csv('../data/pisa/pisa.csv', index_col='Year_Country')
world_bank = pd.read_csv('../data/world_bank/world_bank.csv', index_col='Year_Country')

# %%
df = pd.merge(pd.merge(uis, pisa, left_index=True, right_index=True),
              world_bank, left_index=True, right_index=True)

# %%
df.to_csv('../data/modeling/original_stats.csv', index='Year_Country')

# %%
df.shape
# Out:
# (408, 57)

# %%
negative_features = ([feature for feature in df.columns if 'out' in feature][:-1]
                    + [feature for feature in df.columns if 'petition' in feature]
                    + [feature for feature in df.columns if 'peaters' in feature])

# %%
negative_features
# Out:
# ['Cumulative drop-out rate to the last grade of lower secondary general education, both sexes (%)',
#  'Rate of out-of-school adolescents of lower secondary school age, both sexes (%)',
#  'Rate of out-of-school children of primary school age, both sexes (%)',
#  'Rate of out-of-school youth of upper secondary school age, both sexes (%)',
#  'Rate of out-of-school children, adolescents and youth of primary and secondary school age, both sexes (%)',
#  'Rate of out-of-school adolescents and youth of secondary school age, both sexes (%)',
#  'Repetition rate in lower secondary general education (all grades), both sexes (%)',
#  'Repetition rate in primary education (all grades), both sexes (%)',
#  'Percentage of repeaters in primary education, all grades, both sexes (%)',
#  'Percentage of repeaters in lower secondary general education, all grades, both sexes (%)']

# %%
for feature in negative_features:
    df[feature] = 1 - df[feature]

# %%
mm_scaler = preprocessing.MinMaxScaler(feature_range=(0.9, 1.1))
mm_df = pd.DataFrame(mm_scaler.fit_transform(df),
                     index=df.index, columns=df.columns)
mm_df.head()
# Out:
#                 Gross intake ratio to Grade 1 of primary education, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.942660
# 2000_Algeria                                             0.931875
# 2000_Argentina                                           0.968821
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
#                 Gross enrolment ratio, primary, both sexes (%)  \
# Year_Country
# 2000_Albania                                          0.965837
# 2000_Algeria                                          0.966554
# 2000_Argentina                                        1.013195
# 2000_Australia                                        0.949720
# 2000_Austria                                          0.961927
#
#                 Gross enrolment ratio, primary to tertiary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.924936
# 2000_Algeria                                                  NaN
# 2000_Argentina                                           0.990274
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
#                 Gross enrolment ratio, primary and secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.925246
# 2000_Algeria                                             0.931706
# 2000_Argentina                                           1.009598
# 2000_Australia                                                NaN
# 2000_Austria                                             0.985765
#
#                 Gross enrolment ratio, upper secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.906309
# 2000_Algeria                                             0.903440
# 2000_Argentina                                           0.937758
# 2000_Australia                                                NaN
# 2000_Austria                                             0.962058
#
#                 Gross enrolment ratio, lower secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.952408
# 2000_Algeria                                             0.938056
# 2000_Argentina                                           0.993139
# 2000_Australia                                                NaN
# 2000_Austria                                             0.963278
#
#                 Gross enrolment ratio, tertiary, both sexes (%)  \
# Year_Country
# 2000_Albania                                           0.916788
# 2000_Algeria                                                NaN
# 2000_Argentina                                         0.982925
# 2000_Australia                                              NaN
# 2000_Austria                                                NaN
#
#                 Net enrolment rate, primary, both sexes (%)  \
# Year_Country
# 2000_Albania                                       1.054992
# 2000_Algeria                                       0.981459
# 2000_Argentina                                     1.090874
# 2000_Australia                                     1.035708
# 2000_Austria                                            NaN
#
#                 Net enrolment rate, secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                         0.989347
# 2000_Algeria                                              NaN
# 2000_Argentina                                       1.029752
# 2000_Australia                                            NaN
# 2000_Austria                                         1.061749
#
#                 Net enrolment rate, lower secondary, both sexes (%)  ...  \
# Year_Country                                                         ...
# 2000_Albania                                                  NaN    ...
# 2000_Algeria                                                  NaN    ...
# 2000_Argentina                                            1.05025    ...
# 2000_Australia                                                NaN    ...
# 2000_Austria                                                  NaN    ...
#
#                 Expenditure on secondary education (% of government expenditure on education)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                           0.973779
# 2000_Australia                                           0.983932
# 2000_Austria                                             1.007935
#
#                 Government expenditure per student, secondary (% of GDP per capita)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                             0.954890
# 2000_Argentina                                           0.948253
# 2000_Australia                                                NaN
# 2000_Austria                                             0.994732
#
#                 Expenditure on primary education (% of government expenditure on education)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                           1.004107
# 2000_Australia                                           0.996720
# 2000_Austria                                             0.931337
#
#                 Government expenditure per student, primary (% of GDP per capita)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                             0.922813
# 2000_Argentina                                           0.936290
# 2000_Australia                                           0.960785
# 2000_Austria                                             0.992694
#
#                 Current education expenditure, total (% of total expenditure in public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.059723
# 2000_Austria                                             1.071869
#
#                 Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.064629
# 2000_Austria                                             1.088068
#
#                 Current education expenditure, secondary (% of total expenditure in secondary public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.066200
# 2000_Austria                                             1.070098
#
#                 Current education expenditure, primary (% of total expenditure in primary public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.068148
# 2000_Austria                                             1.068489
#
#                 Literacy rate, adult total (% of people ages 15 and above)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
#                 Literacy rate, youth total (% of people ages 15-24)
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
# [5 rows x 57 columns]

# %%
school_climate = list(uis.columns[:-2])
school_climate
# Out:
# ['Gross intake ratio to Grade 1 of primary education, both sexes (%)',
#  'Gross enrolment ratio, primary, both sexes (%)',
#  'Gross enrolment ratio, primary to tertiary, both sexes (%)',
#  'Gross enrolment ratio, primary and secondary, both sexes (%)',
#  'Gross enrolment ratio, upper secondary, both sexes (%)',
#  'Gross enrolment ratio, lower secondary, both sexes (%)',
#  'Gross enrolment ratio, tertiary, both sexes (%)',
#  'Net enrolment rate, primary, both sexes (%)',
#  'Net enrolment rate, secondary, both sexes (%)',
#  'Net enrolment rate, lower secondary, both sexes (%)',
#  'Adjusted net intake rate to Grade 1 of primary education, both sexes (%)',
#  'Adjusted net enrolment rate, lower secondary, both sexes (%)',
#  'Adjusted net enrolment rate, primary, both sexes (%)',
#  'Total net enrolment rate, primary, both sexes (%)',
#  'Total net enrolment rate, lower secondary, both sexes (%)',
#  'Net enrolment rate, upper secondary, both sexes (%)',
#  'Gross intake ratio to Grade 1 of lower secondary education, both sexes (%)',
#  'Net enrolment rate for compulsory education age group, both sexes (%)',
#  'Total net enrolment rate, upper secondary, both sexes (%)',
#  'Cumulative drop-out rate to the last grade of lower secondary general education, both sexes (%)',
#  'Gross graduation ratio from primary education, both sexes (%)',
#  'Gross graduation ratio from lower secondary education, both sexes (%)',
#  'Percentage of repeaters in primary education, all grades, both sexes (%)',
#  'Rate of out-of-school adolescents of lower secondary school age, both sexes (%)',
#  'Repetition rate in lower secondary general education (all grades), both sexes (%)',
#  'Rate of out-of-school children of primary school age, both sexes (%)',
#  'School life expectancy, primary, both sexes (years)',
#  'School life expectancy, secondary, both sexes (years)',
#  'School life expectancy, primary and secondary, both sexes (years)',
#  'Survival rate to the last grade of lower secondary general education, both sexes (%)',
#  'Effective transition rate from primary to lower secondary general education, both sexes (%)',
#  'Mean years of schooling (ISCED 1 or higher), population 25+ years, both sexes',
#  'Repetition rate in primary education (all grades), both sexes (%)',
#  'Percentage of repeaters in lower secondary general education, all grades, both sexes (%)',
#  'Rate of out-of-school youth of upper secondary school age, both sexes (%)',
#  'Gross graduation ratio from upper secondary education, both sexes (%)',
#  'Rate of out-of-school children, adolescents and youth of primary and secondary school age, both sexes (%)',
#  'Rate of out-of-school adolescents and youth of secondary school age, both sexes (%)']

# %%
school_resources = list(world_bank.columns[:-2])
school_resources
# Out:
# ['Government expenditure on education, total (% of GDP)',
#  'Government expenditure on education, total (% of government expenditure)',
#  'Expenditure on tertiary education (% of government expenditure on education)',
#  'Government expenditure per student, tertiary (% of GDP per capita)',
#  'Expenditure on secondary education (% of government expenditure on education)',
#  'Government expenditure per student, secondary (% of GDP per capita)',
#  'Expenditure on primary education (% of government expenditure on education)',
#  'Government expenditure per student, primary (% of GDP per capita)',
#  'Current education expenditure, total (% of total expenditure in public institutions)',
#  'Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)',
#  'Current education expenditure, secondary (% of total expenditure in secondary public institutions)',
#  'Current education expenditure, primary (% of total expenditure in primary public institutions)']

# %%
learning_outcomes = list(pisa.columns) + list(world_bank.columns[-2:])
learning_outcomes
# Out:
# ['pisa_math',
#  'pisa_reading',
#  'pisa_science',
#  'Literacy rate, adult total (% of people ages 15 and above)',
#  'Literacy rate, youth total (% of people ages 15-24)']

# %%
mm_df['climate_index'] = 1

for feature in school_climate:
    mm_df['climate_index'] = mm_df['climate_index'].multiply(mm_df[feature], fill_value=1)

# %%
mm_df['resources_index'] = 1

for feature in school_resources:
    mm_df['resources_index'] = mm_df['resources_index'].multiply(mm_df[feature], fill_value=1)

# %%
mm_df['learning_index'] = 1

for feature in learning_outcomes:
    mm_df['learning_index'] = mm_df['learning_index'].multiply(mm_df[feature], fill_value=1)

# %%
df_indices = ['climate_index', 'resources_index', 'learning_index']

# %%
mm_scaler = preprocessing.MinMaxScaler(feature_range=(0.9, 1.1))
index_df = pd.DataFrame(mm_scaler.fit_transform(mm_df),
                     index=df.index, columns=mm_df.columns)

# %%
index_df['ed_qual_index'] = (index_df['climate_index'] * index_df['resources_index']
                          * index_df['learning_index'])
index_df.head()
# Out:
#                 Gross intake ratio to Grade 1 of primary education, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.942660
# 2000_Algeria                                             0.931875
# 2000_Argentina                                           0.968821
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
#                 Gross enrolment ratio, primary, both sexes (%)  \
# Year_Country
# 2000_Albania                                          0.965837
# 2000_Algeria                                          0.966554
# 2000_Argentina                                        1.013195
# 2000_Australia                                        0.949720
# 2000_Austria                                          0.961927
#
#                 Gross enrolment ratio, primary to tertiary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.924936
# 2000_Algeria                                                  NaN
# 2000_Argentina                                           0.990274
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
#                 Gross enrolment ratio, primary and secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.925246
# 2000_Algeria                                             0.931706
# 2000_Argentina                                           1.009598
# 2000_Australia                                                NaN
# 2000_Austria                                             0.985765
#
#                 Gross enrolment ratio, upper secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.906309
# 2000_Algeria                                             0.903440
# 2000_Argentina                                           0.937758
# 2000_Australia                                                NaN
# 2000_Austria                                             0.962058
#
#                 Gross enrolment ratio, lower secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                             0.952408
# 2000_Algeria                                             0.938056
# 2000_Argentina                                           0.993139
# 2000_Australia                                                NaN
# 2000_Austria                                             0.963278
#
#                 Gross enrolment ratio, tertiary, both sexes (%)  \
# Year_Country
# 2000_Albania                                           0.916788
# 2000_Algeria                                                NaN
# 2000_Argentina                                         0.982925
# 2000_Australia                                              NaN
# 2000_Austria                                                NaN
#
#                 Net enrolment rate, primary, both sexes (%)  \
# Year_Country
# 2000_Albania                                       1.054992
# 2000_Algeria                                       0.981459
# 2000_Argentina                                     1.090874
# 2000_Australia                                     1.035708
# 2000_Austria                                            NaN
#
#                 Net enrolment rate, secondary, both sexes (%)  \
# Year_Country
# 2000_Albania                                         0.989347
# 2000_Algeria                                              NaN
# 2000_Argentina                                       1.029752
# 2000_Australia                                            NaN
# 2000_Austria                                         1.061749
#
#                 Net enrolment rate, lower secondary, both sexes (%)  ...  \
# Year_Country                                                         ...
# 2000_Albania                                                  NaN    ...
# 2000_Algeria                                                  NaN    ...
# 2000_Argentina                                            1.05025    ...
# 2000_Australia                                                NaN    ...
# 2000_Austria                                                  NaN    ...
#
#                 Current education expenditure, total (% of total expenditure in public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.059723
# 2000_Austria                                             1.071869
#
#                 Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.064629
# 2000_Austria                                             1.088068
#
#                 Current education expenditure, secondary (% of total expenditure in secondary public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.066200
# 2000_Austria                                             1.070098
#
#                 Current education expenditure, primary (% of total expenditure in primary public institutions)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                           1.068148
# 2000_Austria                                             1.068489
#
#                 Literacy rate, adult total (% of people ages 15 and above)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
#                 Literacy rate, youth total (% of people ages 15-24)  \
# Year_Country
# 2000_Albania                                                  NaN
# 2000_Algeria                                                  NaN
# 2000_Argentina                                                NaN
# 2000_Australia                                                NaN
# 2000_Austria                                                  NaN
#
#                 climate_index  resources_index  learning_index  ed_qual_index
# Year_Country
# 2000_Albania         0.910092         0.952688        0.939724       0.814772
# 2000_Algeria         0.904644         0.952158        0.962724       0.829256
# 2000_Argentina       0.952198         0.926799        0.962724       0.849601
# 2000_Australia       0.913879         1.020629        0.988161       0.921688
# 2000_Austria         0.922336         1.027773        0.978419       0.927494
#
# [5 rows x 61 columns]

# %%
index_df.to_csv('../data/modeling/scaled_stats.csv', index='Year_Country')
